# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/jaehyungyoo/Desktop/rltrader-master/data/v2/005380.csv')
data.head()
# Out:
#        date      open      high       low     close    volume   per   pbr  \
# 0  20160104  147500.0  148000.0  143500.0  144000.0  445332.0  7.67  0.43
# 1  20160105  143000.0  145000.0  142000.0  143500.0  530496.0  7.67  0.43
# 2  20160106  144000.0  145000.0  139000.0  140000.0  769406.0  7.67  0.43
# 3  20160107  138500.0  140000.0  137500.0  137500.0  586187.0  7.67  0.43
# 4  20160108  134500.0  138000.0  133500.0  136500.0  888701.0  7.67  0.43
#
#     roe  market_kospi_ma5_ratio  market_kospi_ma20_ratio  \
# 0  6.06                1.014067                 1.020727
# 1  6.06                1.015097                 1.030705
# 2  6.06                1.009296                 1.035409
# 3  6.06                0.996236                 1.024228
# 4  6.06                1.000425                 1.027504
#
#    market_kospi_ma60_ratio  market_kospi_ma120_ratio  bond_k3y_ma5_ratio  \
# 0                 1.003090                  0.982268            1.000721
# 1                 1.012278                  0.991928            1.000419
# 2                 1.016705                  0.997317            1.000556
# 3                 1.005281                  0.987199            1.000638
# 4                 1.009328                  0.992360            0.999909
#
#    bond_k3y_ma20_ratio  bond_k3y_ma60_ratio  bond_k3y_ma120_ratio
# 0             1.002284             1.000295              1.000591
# 1             1.002215             1.000242              1.000456
# 2             1.002633             1.000726              1.000861
# 3             1.002920             1.001104              1.001178
# 4             1.002073             1.000535              1.000542

# %%
COLUMNS_CHART_DATA = ['date', 'open', 'high', 'low', 'close', 'volume']

COLUMNS_TRAINING_DATA_V1 = [
    'open_lastclose_ratio', 'high_close_ratio', 'low_close_ratio',
    'close_lastclose_ratio', 'volume_lastvolume_ratio',
    'close_ma5_ratio', 'volume_ma5_ratio',
    'close_ma10_ratio', 'volume_ma10_ratio',
    'close_ma20_ratio', 'volume_ma20_ratio',
    'close_ma60_ratio', 'volume_ma60_ratio',
    'close_ma120_ratio', 'volume_ma120_ratio',
]
COLUMNS_TRAINING_DATA_V2 = [
    'per', 'pbr', 'roe',
    'open_lastclose_ratio', 'high_close_ratio', 'low_close_ratio',
    'close_lastclose_ratio', 'volume_lastvolume_ratio',
    'close_ma5_ratio', 'volume_ma5_ratio',
    'close_ma10_ratio', 'volume_ma10_ratio',
    'close_ma20_ratio', 'volume_ma20_ratio',
    'close_ma60_ratio', 'volume_ma60_ratio',
    'close_ma120_ratio', 'volume_ma120_ratio',
    'market_kospi_ma5_ratio', 'market_kospi_ma20_ratio', 
    'market_kospi_ma60_ratio', 'market_kospi_ma120_ratio', 
    'bond_k3y_ma5_ratio', 'bond_k3y_ma20_ratio', 
    'bond_k3y_ma60_ratio', 'bond_k3y_ma120_ratio'
]

# %%
def preprocess(data):
    windows = [5, 10, 20, 60, 120]
    for window in windows:
        data['close_ma{}'.format(window)] = \
            data['close'].rolling(window).mean()
        data['volume_ma{}'.format(window)] = \
            data['volume'].rolling(window).mean()
        data['close_ma%d_ratio' % window] = \
            (data['close'] - data['close_ma%d' % window]) \
            / data['close_ma%d' % window]
        data['volume_ma%d_ratio' % window] = \
            (data['volume'] - data['volume_ma%d' % window]) \
            / data['volume_ma%d' % window]
    data['open_lastclose_ratio'] = np.zeros(len(data))
    data.loc[1:, 'open_lastclose_ratio'] = \
        (data['open'][1:].values - data['close'][:-1].values) \
        / data['close'][:-1].values
    data['high_close_ratio'] = \
        (data['high'].values - data['close'].values) \
        / data['close'].values
    data['low_close_ratio'] = \
        (data['low'].values - data['close'].values) \
        / data['close'].values
    data['close_lastclose_ratio'] = np.zeros(len(data))
    data.loc[1:, 'close_lastclose_ratio'] = \
        (data['close'][1:].values - data['close'][:-1].values) \
        / data['close'][:-1].values
    data['volume_lastvolume_ratio'] = np.zeros(len(data))
    data.loc[1:, 'volume_lastvolume_ratio'] = \
        (data['volume'][1:].values - data['volume'][:-1].values) \
        / data['volume'][:-1] \
            .replace(to_replace=0, method='ffill') \
            .replace(to_replace=0, method='bfill').values
        
    return data;

# %%
data = preprocess(data);

# %%
data.head()
# Out:
#        date      open      high       low     close    volume   per   pbr  \
# 0  20160104  147500.0  148000.0  143500.0  144000.0  445332.0  7.67  0.43
# 1  20160105  143000.0  145000.0  142000.0  143500.0  530496.0  7.67  0.43
# 2  20160106  144000.0  145000.0  139000.0  140000.0  769406.0  7.67  0.43
# 3  20160107  138500.0  140000.0  137500.0  137500.0  586187.0  7.67  0.43
# 4  20160108  134500.0  138000.0  133500.0  136500.0  888701.0  7.67  0.43
#
#     roe  market_kospi_ma5_ratio  ...  volume_ma60_ratio  close_ma120  \
# 0  6.06                1.014067  ...                NaN          NaN
# 1  6.06                1.015097  ...                NaN          NaN
# 2  6.06                1.009296  ...                NaN          NaN
# 3  6.06                0.996236  ...                NaN          NaN
# 4  6.06                1.000425  ...                NaN          NaN
#
#    volume_ma120  close_ma120_ratio  volume_ma120_ratio  open_lastclose_ratio  \
# 0           NaN                NaN                 NaN              0.000000
# 1           NaN                NaN                 NaN             -0.006944
# 2           NaN                NaN                 NaN              0.003484
# 3           NaN                NaN                 NaN             -0.010714
# 4           NaN                NaN                 NaN             -0.021818
#
#    high_close_ratio  low_close_ratio  close_lastclose_ratio  \
# 0          0.027778        -0.003472               0.000000
# 1          0.010453        -0.010453              -0.003472
# 2          0.035714        -0.007143              -0.024390
# 3          0.018182         0.000000              -0.017857
# 4          0.010989        -0.021978              -0.007273
#
#    volume_lastvolume_ratio
# 0                 0.000000
# 1                 0.191237
# 2                 0.450352
# 3                -0.238130
# 4                 0.516071
#
# [5 rows x 42 columns]

# %%
data.to_csv('test.csv')

# %%
data.loc[1:,'close']
# Out:
# 1      143500.0
# 2      140000.0
# 3      137500.0
# 4      136500.0
# 5      140000.0
#          ...
# 974    122500.0
# 975    122000.0
# 976    122500.0
# 977    120500.0
# 978    120500.0
# Name: close, Length: 978, dtype: float64

# %%
data['close'][1:]
# Out:
# 1      143500.0
# 2      140000.0
# 3      137500.0
# 4      136500.0
# 5      140000.0
#          ...
# 974    122500.0
# 975    122000.0
# 976    122500.0
# 977    120500.0
# 978    120500.0
# Name: close, Length: 978, dtype: float64

# %%
data['open_lastclose_ratio'] = np.zeros(len(data))
data.head()
# Out:
#        date      open      high       low     close    volume   per   pbr  \
# 0  20160104  147500.0  148000.0  143500.0  144000.0  445332.0  7.67  0.43
# 1  20160105  143000.0  145000.0  142000.0  143500.0  530496.0  7.67  0.43
# 2  20160106  144000.0  145000.0  139000.0  140000.0  769406.0  7.67  0.43
# 3  20160107  138500.0  140000.0  137500.0  137500.0  586187.0  7.67  0.43
# 4  20160108  134500.0  138000.0  133500.0  136500.0  888701.0  7.67  0.43
#
#     roe  market_kospi_ma5_ratio  ...  volume_ma20_ratio  close_ma60  \
# 0  6.06                1.014067  ...                NaN         NaN
# 1  6.06                1.015097  ...                NaN         NaN
# 2  6.06                1.009296  ...                NaN         NaN
# 3  6.06                0.996236  ...                NaN         NaN
# 4  6.06                1.000425  ...                NaN         NaN
#
#    volume_ma60  close_ma60_ratio  volume_ma60_ratio  close_ma120  \
# 0          NaN               NaN                NaN          NaN
# 1          NaN               NaN                NaN          NaN
# 2          NaN               NaN                NaN          NaN
# 3          NaN               NaN                NaN          NaN
# 4          NaN               NaN                NaN          NaN
#
#    volume_ma120  close_ma120_ratio  volume_ma120_ratio  open_lastclose_ratio
# 0           NaN                NaN                 NaN                   0.0
# 1           NaN                NaN                 NaN                   0.0
# 2           NaN                NaN                 NaN                   0.0
# 3           NaN                NaN                 NaN                   0.0
# 4           NaN                NaN                 NaN                   0.0
#
# [5 rows x 38 columns]

# %%
data['open'][:].values
# Out:
# array([147500., 143000., 144000., 138500., 134500., 134500., 140500.,
#        140500., 138500., 141000., 137500., 138000., 139500., 136000.,
#        138000., 140000., 136500., 135500., 135500., 135000., 132000.,
#        131500., 127500., 130000., 132000., 130500., 131500., 137500.,
#        139500., 142000., 147500., 147000., 147500., 148000., 147500.,
#        149500., 148000., 145500., 150000., 151500., 146000., 147500.,
#        145000., 147000., 149000., 147500., 150000., 148500., 147000.,
#        148000., 148000., 151000., 155500., 159500., 156500., 154500.,
#        153000., 155000., 156000., 156000., 152500., 148500., 144000.,
#        144000., 143500., 146000., 147500., 146000., 150000., 150500.,
#        150000., 155000., 153500., 152000., 152000., 151000., 149000.,
#        152000., 148500., 146500., 142000., 143000., 141500., 138500.,
#        136500., 140500., 138000., 136000., 136500., 135500., 135000.,
#        132500., 134000., 133000., 133000., 134500., 136000., 136000.,
#        136000., 136500., 137500., 138500., 138000., 138500., 138500.,
#        139500., 138500., 138000., 135500., 138000., 135500., 136000.,
#        136000., 136500., 138500., 140500., 140500., 141000., 141500.,
#        140000., 138000., 136500., 138000., 136500., 134000., 131500.,
#        131000., 130500., 131500., 133000., 134000., 132000., 133000.,
#        131500., 129500., 130000., 130000., 129500., 135000., 137000.,
#        137500., 135000., 132500., 135500., 133000., 132500., 130500.,
#        134000., 135000., 135500., 134000., 135000., 136000., 133500.,
#        134500., 133000., 132500., 133000., 132000., 136000., 136500.,
#        134000., 133500., 132000., 133000., 132500., 136000., 138500.,
#        139500., 139000., 138000., 138500., 140000., 137000., 137000.,
#        137500., 138000., 139500., 140500., 140000., 141000., 138500.,
#        138500., 138500., 137500., 139000., 138500., 134000., 135000.,
#        134500., 136500., 133500., 134500., 133500., 134500., 133500.,
#        132500., 134500., 135000., 137500., 139000., 138000., 139000.,
#        141000., 141000., 139500., 136500., 137500., 137500., 138000.,
#        135000., 130000., 132000., 131500., 130500., 131000., 131500.,
#        130000., 133500., 134500., 133500., 135500., 135000., 133000.,
#        133500., 133000., 134000., 134500., 135500., 138000., 138500.,
#        142000., 146000., 144500., 144500., 142000., 141000., 140000.,
#        141500., 144500., 143000., 143000., 143500., 144500., 142500.,
